# %% [markdown]
# ## **Matplotlib**
#
# - Line Plot
# - Scatter Plot
# - Histograms
# - Scale Transform
# - Labels/Ticks/Sizes/Colors

# %% [markdown]
# ## Line Plot
#
# ```python
# import matplotlib.pyplot as plt
# plt.show(x,y)
# plt.show()
# ```

# %%
# loading the libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading dataset
data = pd.read_csv('gapminder_tidy.csv')
df = data.copy()
df.head()
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#     gdp-1      region
# 0  1182.0  South Asia
# 1  1168.0  South Asia
# 2  1173.0  South Asia
# 3  1187.0  South Asia
# 4  1178.0  South Asia

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'fertility', 'life', 'population', 'child_mortality',
#        'gdp', 'gdp-1', 'region'],
#       dtype='object')

# %%
# changing column names
df.columns = ['country', 'year', 'fertility', 'life_expectancy', 'population', 'child_mortality', 'gdp', 'gdp-1', 'region']
df.head()
# Out:
#        country  year  fertility  life_expectancy  population  child_mortality  \
# 0  Afghanistan  1964      7.671           33.639  10474903.0            339.7
# 1  Afghanistan  1965      7.671           34.152  10697983.0            334.1
# 2  Afghanistan  1966      7.671           34.662  10927724.0            328.7
# 3  Afghanistan  1967      7.671           35.170  11163656.0            323.3
# 4  Afghanistan  1968      7.671           35.674  11411022.0            318.1
#
#       gdp   gdp-1      region
# 0  1182.0  1182.0  South Asia
# 1  1182.0  1168.0  South Asia
# 2  1168.0  1173.0  South Asia
# 3  1173.0  1187.0  South Asia
# 4  1187.0  1178.0  South Asia

# %%
# aggregating population on year
# calculating population of each year in the world
df_popworld = df.groupby(['year'])['population'].sum().reset_index()
df_popworld.head()
# Out:
#    year    population
# 0  1964  3.268989e+09
# 1  1965  3.333022e+09
# 2  1966  3.400742e+09
# 3  1967  3.471753e+09
# 4  1968  3.545277e+09

# %%
df_popworld.tail()
# Out:
#     year    population
# 45  2009  6.816619e+09
# 46  2010  6.894751e+09
# 47  2011  6.972892e+09
# 48  2012  7.050996e+09
# 49  2013  7.128887e+09

# %%
# make a line plot: year on the x-axis and population on y-axis
year = df_popworld['year']
population = df_popworld['population']
plt.plot(year,population)

# display the plot
plt.show()

# %%
plt.plot(df['gdp'], df['life_expectancy'])
plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# - As both are continuous variables so we will make Scatter plot for this

# %%
plt.scatter(df['gdp'], df['life_expectancy'])
plt.show()

# %%
# put the x-axis on a lograthmic scale
plt.scatter(df['gdp'], df['life_expectancy'])
plt.xscale('log')
plt.show()

# %% [markdown]
# - `xscale('log')` A logarithmic scale is a non-linear scale used when there is range of quantities.
# - Common used include earthquake strength, sound loudness, light intensity and pH solutions.
# - Logarithmic scales are also used in slide rules for multiplying or dividing numbers by adding and subtracting lenghts on scale.

# %%
# make scatter plot on specific year
df_2011 = df[df['year'] == 2011]
plt.scatter(df_2011['population'], df_2011['life_expectancy'])
plt.xscale('log')
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.hist(df['life_expectancy'])
plt.show()

# %% [markdown]
# - By default, Python sets the number of bins to 10.
# - The number of bins is important.
# - Too few bins will oversimplify reality and won't show you the details.
# - Too many bins will overcomplicate reality and won't show the bigger picture.
# - Too control the number of bins divide your data in, you can set the bin arguments.

# %%
plt.hist(df_2011['life_expectancy'])
plt.show()

# %%
df_2011['life_expectancy'].describe()
# Out:
# count    202.000000
# mean      70.238072
# std        9.247171
# min       45.110000
# 25%       65.339000
# 50%       73.154500
# 75%       76.968750
# max       83.255000
# Name: life_expectancy, dtype: float64

# %%
plt.hist(df_2011['life_expectancy'], bins=5)
plt.show()

# %%
df_1964 = df[df['year'] == 1964]
df_1964.head()
# Out:
#                  country  year  fertility  life_expectancy  population  \
# 0            Afghanistan  1964      7.671           33.639  10474903.0
# 50               Albania  1964      5.711           65.475   1817098.0
# 100              Algeria  1964      7.653           47.953  11654905.0
# 150               Angola  1964      7.425           34.604   5337063.0
# 200  Antigua and Barbuda  1964      4.250           63.775     58653.0
#
#      child_mortality     gdp   gdp-1                      region
# 0             339.70  1182.0  1182.0                  South Asia
# 50            122.67  3023.0  3129.0       Europe & Central Asia
# 100           247.30  5693.0  5916.0  Middle East & North Africa
# 150           305.20  4573.0  4840.0          Sub-Saharan Africa
# 200            72.78  5008.0  5133.0                     America

# %% [markdown]
# - Making two plots side by side

# %%
# subplot1
plt.subplot(1,2,1)
plt.hist(df_2011['life_expectancy'], bins=15)

# subplot2
plt.subplot(1,2,2)
plt.hist(df_1964['life_expectancy'], bins=15)

plt.show()

# %% [markdown]
# - Both plots in one graph

# %%
plt.hist(df_2011['life_expectancy'], bins=15)
plt.hist(df_1964['life_expectancy'], bins=15)
plt.show()

# %%
# specify figure size
plt.figure(figsize=(15,6))

# subplot1
plt.subplot(1,2,1)
plt.hist(df_2011['life_expectancy'], bins=15)

# subplot2
plt.subplot(1,2,2)
plt.hist(df_1964['life_expectancy'], bins=15)

plt.show()

# %% [markdown]
# ## Exercise
#
# - Checking if life expectancy is increasing with years or not

# %%
df.head()
# Out:
#        country  year  fertility  life_expectancy  population  child_mortality  \
# 0  Afghanistan  1964      7.671           33.639  10474903.0            339.7
# 1  Afghanistan  1965      7.671           34.152  10697983.0            334.1
# 2  Afghanistan  1966      7.671           34.662  10927724.0            328.7
# 3  Afghanistan  1967      7.671           35.170  11163656.0            323.3
# 4  Afghanistan  1968      7.671           35.674  11411022.0            318.1
#
#       gdp   gdp-1      region
# 0  1182.0  1182.0  South Asia
# 1  1182.0  1168.0  South Asia
# 2  1168.0  1173.0  South Asia
# 3  1173.0  1187.0  South Asia
# 4  1187.0  1178.0  South Asia

# %%
df_le = df.groupby('year')['life_expectancy'].mean().reset_index()
df_le.head()
# Out:
#    year  life_expectancy
# 0  1964        56.041621
# 1  1965        56.408304
# 2  1966        56.818852
# 3  1967        57.234705
# 4  1968        57.579042

# %%
plt.figure(figsize=(15,5))
plt.plot(df_le['year'], df_le['life_expectancy'])
plt.title('Life Expectancy Over the Years')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.show()

# %% [markdown]
# ##  **Sizes**

# %%
# import numpy
import numpy as np

# %%
# store pop as as numpy array: np_pop
df_2011['pop_mill'] = df_2011['population']/1000000
df_2011.head()
# Out:
# C:\Users\khan\AppData\Local\Temp\ipykernel_16388\1150404632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2011['pop_mill'] = df_2011['population']/1000000
#                  country  year  fertility  life_expectancy  population  \
# 47           Afghanistan  2011      5.395           60.079  32358260.0
# 97               Albania  2011      1.748           76.979   3215988.0
# 147              Algeria  2011      2.829           70.747  35980193.0
# 197               Angola  2011      6.099           51.094  19618432.0
# 247  Antigua and Barbuda  2011      2.115           75.610     89612.0
#
#      child_mortality      gdp    gdp-1                      region   pop_mill
# ...

# %%
np_pop = df_2011['pop_mill']
print(np_pop)
# double np_pop
np_pop = np_pop * 2
# Out:
# 47       32.358260
# 97        3.215988
# 147      35.980193
# 197      19.618432
# 247       0.089612
#            ...
# 9898      4.152369
# 9948      0.548377
# 9998     24.799880
# 10048    13.474959
# 10098    12.754378
# Name: pop_mill, Length: 202, dtype: float64

# %%
# scatter plot
plt.scatter(df_2011['gdp'], df_2011['life_expectancy'], s=np_pop)
plt.xscale('log')
plt.xlabel('GDP per Capital [in USD]')
plt.ylabel('Life Expectancy [in Years]')
plt.title('World Development in 2011')
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']
plt.xticks(tick_val, tick_lab)

plt.show()

# %% [markdown]
# ### Adding Color

# %%
df['region'].unique()
# Out:
# array(['South Asia', 'Europe & Central Asia',
#        'Middle East & North Africa', 'Sub-Saharan Africa', 'America',
#        'East Asia & Pacific'], dtype=object)

# %%
col = {
    'South Asia' : 'red', 
    'Europe & Central Asia' : 'green',
    'Middle East & North Africa' : 'blue', 
    'Sub-Saharan Africa' : 'yellow', 
    'America' : 'orange',
    'East Asia & Pacific' : 'black'
}

# %%
# add the color code infront of each region
df_2011['col'] = df_2011['region'].map(col)
df_2011.head()
# Out:
# C:\Users\khan\AppData\Local\Temp\ipykernel_16388\1397770998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2011['col'] = df_2011['region'].map(col)
#                  country  year  fertility  life_expectancy  population  \
# 47           Afghanistan  2011      5.395           60.079  32358260.0
# 97               Albania  2011      1.748           76.979   3215988.0
# 147              Algeria  2011      2.829           70.747  35980193.0
# 197               Angola  2011      6.099           51.094  19618432.0
# 247  Antigua and Barbuda  2011      2.115           75.610     89612.0
#
#      child_mortality      gdp    gdp-1                      region   pop_mill  \
# ...

# %%
plt.scatter(df_2011['gdp'], df_2011['life_expectancy'], s = np_pop, c = df_2011['col'] , alpha = 0.7)
# previous customization
plt.xscale('log')
plt.xlabel('GDP per Capital [in USD]')
plt.ylabel('Life Expectancy [in Years]')
plt.title('World Development in 2011')
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']
plt.xticks(tick_val, tick_lab)

plt.show()

# %%
# figure size
plt.figure(figsize=(13, 7))

plt.scatter(df_2011['gdp'], df_2011['life_expectancy'], s = np_pop, c = df_2011['col'] , alpha = 0.7)
# previous customization
plt.xscale('log')
plt.xlabel('GDP per Capital [in USD]')
plt.ylabel('Life Expectancy [in Years]')
plt.title('World Development in 2011')
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']
plt.xticks(tick_val, tick_lab)

# Additional Customization
plt.text(4050,69,'India')
plt.text(8700,78.5,'China')
plt.text(3000,68,'Pakistan')
plt.grid(True)

# show plot
plt.show()
